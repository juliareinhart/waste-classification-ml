# %% [markdown]
# (Jupyter version): Export YOLOv8 → Core ML

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO("/Users/car/CSUChico/CSCI611/yolov8/runs/realwaste_detect_mps/weights/best.pt")

# Export to Core ML
model.export(format="coreml")
# Out:
# Ultralytics 8.4.41 🚀 Python-3.10.20 torch-2.11.0 CPU (Apple M5)
# Model summary (fused): 73 layers, 3,007,403 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/Users/car/CSUChico/CSCI611/yolov8/runs/realwaste_detect_mps/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 13, 8400) (6.0 MB)
#
# CoreML: starting export with coremltools 9.0...
# ...
# Running MIL default pipeline:   0%|                                                         | 0/95 [00:00<?, ? passes/s]/opt/anaconda3/envs/yolo/lib/python3.10/site-packages/coremltools/converters/mil/mil/passes/defs/preprocess.py:273: UserWarning: Output, '910', of the source model, has been renamed to 'var_910' in the Core ML model.
#   warnings.warn(msg.format(var.name, new_name))
# ...
# Running MIL backend_mlprogram pipeline: 100%|█████████████████████████████████████| 12/12 [00:00<00:00, 326.50 passes/s]
# ...
