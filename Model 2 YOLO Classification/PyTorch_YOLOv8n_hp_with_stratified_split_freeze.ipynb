# %% [markdown]
# Explore hyper-parameters

# %% [markdown]
# Training YOLOv8n with Real Waste images in Colab.
# This will capture training time.

# %%
import os
print(os.getcwd())
# Out:
# /Users/car/611/YOLOv8-PyTorch

# %% [markdown]
# Because Colab uses temporarly environments, we need to install ultralytics every time I need to downlaod a model and train it.

# %%
#skipping this cell bc i am running locally on my mac so i can skip the content code

#import os
#print(os.listdir('/content'))

# %% [markdown]
# Mount google drive in this environment

# %%
# I am running this locally on my Mac so I can skip these lines

#from google.colab import drive
#drive.mount('/content/drive')

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.47-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from ultralytics) (2.4.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from ultralytics) (2.33.1)
# Requirement already satisfied: scipy>=1.4.1 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from ultralytics) (2.11.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from ultralytics) (0.26.0)
# Requirement already satisfied: psutil>=5.8.0 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from ultralytics) (7.0.0)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.40.1-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.19-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=3 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.40.1 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.40.1-cp310-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2026.4.22)
# Requirement already satisfied: filelock in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2026.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/ml/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.4.47-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.2 MB/s  0:00:003.4 MB/s eta 0:00:01
# Downloading polars-1.40.1-py3-none-any.whl (828 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.7/828.7 kB 3.3 MB/s  0:00:003.7 MB/s eta 0:00:01
# Downloading polars_runtime_32-1.40.1-cp310-abi3-macosx_11_0_arm64.whl (46.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 MB 2.2 MB/s  0:00:20 eta 0:00:010:00:01
# Downloading ultralytics_thop-2.0.19-py3-none-any.whl (28 kB)
# Installing collected packages: polars-runtime-32, polars, ultralytics-thop, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [ultralytics] 3/4 [ultralytics]
# Successfully installed polars-1.40.1 polars-runtime-32-1.40.1 ultralytics-8.4.47 ultralytics-thop-2.0.19

# %% [markdown]
# Insatall sklearn

# %%
#test to make sure input and output directories exist

from pathlib import Path

###SOURCE_DIR = Path("data/realwaste-main/RealWaste") Julia's path
SOURCE_DIR = Path("RealWaste")

print("SOURCE_DIR exists:", SOURCE_DIR.exists())
print("Folders inside SOURCE_DIR:")

if SOURCE_DIR.exists():
    for item in SOURCE_DIR.iterdir():
        if item.is_dir():
            print(item.name)
# Out:
# SOURCE_DIR exists: True
# Folders inside SOURCE_DIR:
# Paper
# Metal
# images
# Cardboard
# labels
# Food Organics
# Glass
# Vegetation
# Textile Trash
# Miscellaneous Trash
# Plastic

# %% [markdown]
# Create stratified YOLO classification dataset

# %% [markdown]
# Install scikit-learn

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /opt/anaconda3/envs/yolo/lib/python3.10/site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in /opt/anaconda3/envs/yolo/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 65.0 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn]━━━━━ 2/3 [scikit-learn]
# Successfully installed joblib-1.5.3 scikit-learn-1.7.2 threadpoolctl-3.6.0

# %%
#switching from using Yaml Classification to a stratified split
#no longer a random split but a stratified split

from pathlib import Path
import shutil
from sklearn.model_selection import train_test_split
from collections import Counter

SOURCE_DIR = Path("realwaste-yolo/RealWaste")
OUTPUT_DIR = Path("outputs_for_YOLO_classification_stratified_dataset")

train_ratio = 0.70
seed = 42

image_extensions = {".jpg", ".jpeg", ".png", ".webp"}

if OUTPUT_DIR.exists():
    shutil.rmtree(OUTPUT_DIR)

for split in ["train", "val", "test"]:
    (OUTPUT_DIR / split).mkdir(parents=True, exist_ok=True)

image_paths = []
targets = []

class_names = sorted([p.name for p in SOURCE_DIR.iterdir() if p.is_dir()])

for class_name in class_names:
    class_folder = SOURCE_DIR / class_name
    for img_path in class_folder.iterdir():
        if img_path.suffix.lower() in image_extensions:
            image_paths.append(img_path)
            targets.append(class_name)

print("Classes found:", class_names)
print("Total images:", len(image_paths))
print("Original class counts:", Counter(targets))

train_paths, temp_paths, train_targets, temp_targets = train_test_split(
    image_paths,
    targets,
    train_size=train_ratio,
    stratify=targets,
    random_state=seed
)

val_paths, test_paths, val_targets, test_targets = train_test_split(
    temp_paths,
    temp_targets,
    test_size=0.5,
    stratify=temp_targets,
    random_state=seed
)

def copy_split(paths, labels, split_name):
    for src_path, class_name in zip(paths, labels):
        dest_dir = OUTPUT_DIR / split_name / class_name
        dest_dir.mkdir(parents=True, exist_ok=True)
        shutil.copy2(src_path, dest_dir / src_path.name)

copy_split(train_paths, train_targets, "train")
copy_split(val_paths, val_targets, "val")
copy_split(test_paths, test_targets, "test")

print("Done creating stratified YOLO classification folders!")
print("Train:", len(train_paths), Counter(train_targets))
print("Val:", len(val_paths), Counter(val_targets))
print("Test:", len(test_paths), Counter(test_targets))
# Out:
# Classes found: ['Cardboard', 'Food Organics', 'Glass', 'Metal', 'Miscellaneous Trash', 'Paper', 'Plastic', 'Textile Trash', 'Vegetation', 'images', 'labels']
# Total images: 4752
# Original class counts: Counter({'Plastic': 921, 'Metal': 790, 'Paper': 500, 'Miscellaneous Trash': 495, 'Cardboard': 461, 'Vegetation': 436, 'Glass': 420, 'Food Organics': 411, 'Textile Trash': 318})
# Done creating stratified YOLO classification folders!
# Train: 3326 Counter({'Plastic': 645, 'Metal': 553, 'Paper': 350, 'Miscellaneous Trash': 346, 'Cardboard': 323, 'Vegetation': 305, 'Glass': 294, 'Food Organics': 288, 'Textile Trash': 222})
# Val: 713 Counter({'Plastic': 138, 'Metal': 119, 'Paper': 75, 'Miscellaneous Trash': 74, 'Cardboard': 69, 'Vegetation': 66, 'Glass': 63, 'Food Organics': 61, 'Textile Trash': 48})
# Test: 713 Counter({'Plastic': 138, 'Metal': 118, 'Paper': 75, 'Miscellaneous Trash': 75, 'Cardboard': 69, 'Vegetation': 65, 'Glass': 63, 'Food Organics': 62, 'Textile Trash': 48})

# %%
#verification after cell 13 to ensure INPUT and OUTPUT directories exist

from pathlib import Path
from collections import Counter

OUTPUT_DIR = Path("outputs_for_YOLO_classification_stratified_dataset")

for split in ["train", "val", "test"]:
    split_dir = OUTPUT_DIR / split
    print(f"\n{split.upper()} exists:", split_dir.exists())

    class_counts = {}
    for class_dir in sorted(split_dir.iterdir()):
        if class_dir.is_dir():
            count = len(list(class_dir.glob("*")))
            class_counts[class_dir.name] = count

    print(class_counts)
# Out:
# TRAIN exists: True
# {'Cardboard': 323, 'Food Organics': 288, 'Glass': 294, 'Metal': 553, 'Miscellaneous Trash': 346, 'Paper': 350, 'Plastic': 645, 'Textile Trash': 222, 'Vegetation': 305}
#
# VAL exists: True
# {'Cardboard': 69, 'Food Organics': 61, 'Glass': 63, 'Metal': 119, 'Miscellaneous Trash': 74, 'Paper': 75, 'Plastic': 138, 'Textile Trash': 48, 'Vegetation': 66}
#
# TEST exists: True
# {'Cardboard': 69, 'Food Organics': 62, 'Glass': 63, 'Metal': 118, 'Miscellaneous Trash': 75, 'Paper': 75, 'Plastic': 138, 'Textile Trash': 48, 'Vegetation': 65}

# %% [markdown]
# Training Block

# %%
from ultralytics import YOLO
import torch
from datetime import datetime

# Start time
start_time = datetime.now()
print("Training started at:", start_time.strftime("%Y-%m-%d %H:%M:%S"))
# ======> Train the model
def main():

    # 1. Check for NVIDIA GPU (Colab/PC)
    # 2. Check for Apple Silicon (Mac)
    # 3. Default to CPU
    device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"

    print(f"I am training on: {device.upper()}")

    ### Clasify model.
    model = YOLO("yolov8n-cls.pt")

    model.train(
        ### data="realwaste-yolo/RealWaste/data.yaml",
        ### '/content/RealWaste/data.yaml'
        data="outputs_for_YOLO_classification_stratified_dataset",
        epochs=10, ###==> Hyper-parameters
        lr0=0.005,
        lrf=0.1,
        momentum=0.9,
        weight_decay=0.0001,
        ###warmup_epochs=5,
        ###warmup_momentum=0.8,
        ###warmup_bias_lr=0.1, ###<==
        imgsz=224,
        batch=16,
        patience=5,
        device=device,
        workers=5,  # safer in Jupyter if needed
        project="runs",
        name="yolov8n_cls_stratified_10epochs"
    )

if __name__ == "__main__":
    main()
# <=====

# End time
end_time = datetime.now()
print("Training ended at:", end_time.strftime("%Y-%m-%d %H:%M:%S"))

# Elapsed time
elapsed = end_time - start_time

# Format nicely (hours, minutes, seconds)
hours, remainder = divmod(elapsed.total_seconds(), 3600)
minutes, seconds = divmod(remainder, 60)

print(f"Elapsed time: {int(hours)}h {int(minutes)}m {int(seconds)}s")
# Out:
# Training started at: 2026-05-13 21:12:10
# I am training on: MPS
# New https://pypi.org/project/ultralytics/8.4.50 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.41 🚀 Python-3.10.20 torch-2.11.0 MPS (Apple M5)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=outputs_for_YOLO_classification_stratified_dataset, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.005, lrf=0.1, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.9, mosaic=1.0, multi_scale=0.0, name=yolov8n_cls_stratified_10epochs, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/Users/car/CSUChico/CSCI611/yolov8/runs/classify/runs/yolov8n_cls_stratified_10epochs, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0001, workers=5, workspace=None
# train: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/train... found 3326 images in 9 classes ✅
# val: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/val... found 713 images in 9 classes ✅
# test: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/test... found 713 images in 9 classes ✅
# Overriding model.yaml nc=1000 with nc=9
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    341769  ultralytics.nn.modules.head.Classify         [256, 9]
# YOLOv8n-cls summary: 56 layers, 1,449,817 parameters, 1,449,817 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 685.9±200.0 MB/s, size: 133.2 KB)
# train: Scanning /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/train... 3326 images, 0 corrupt: 100% ━━━━━━━━━━━━ 3326/3326 11.9Kit/s 0.3s.2s
# train: New cache created: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5032.3±1663.5 MB/s, size: 152.3 KB)
# val: Scanning /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/val... 713 images, 0 corrupt: 100% ━━━━━━━━━━━━ 713/713 11.1Kit/s 0.1s
# val: New cache created: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.005' and 'momentum=0.9' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000769, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0001), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to /Users/car/CSUChico/CSCI611/yolov8/runs/classify/runs/yolov8n_cls_stratified_10epochs
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/10      1.13G      1.706         14        224: 100% ━━━━━━━━━━━━ 208/208 10.9it/s 19.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 23/23 9.8it/s 2.3s0.1s
#                    all      0.669      0.972
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/10      1.13G     0.9305         14        224: 100% ━━━━━━━━━━━━ 208/208 13.2it/s 15.7s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 23/23 11.0it/s 2.1s0.1s
#                    all      0.745      0.989
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/10      1.12G     0.7404         14        224: 100% ━━━━━━━━━━━━ 208/208 13.2it/s 15.8s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 23/23 10.7it/s 2.1s0.1s
#                    all      0.808      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/10      1.11G     0.6204         14        224: 100% ━━━━━━━━━━━━ 208/208 13.3it/s 15.7s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 23/23 10.5it/s 2.2s.1s
#                    all      0.825       0.99
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/10      1.11G     0.5157         14        224: 100% ━━━━━━━━━━━━ 208/208 13.2it/s 15.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 23/23 10.3it/s 2.2s.1s
#                    all      0.849      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/10      1.11G     0.4417         14        224: 100% ━━━━━━━━━━━━ 208/208 13.2it/s 15.7s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 23/23 10.9it/s 2.1s0.1s
#                    all      0.864      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/10      1.11G      0.378         14        224: 100% ━━━━━━━━━━━━ 208/208 13.1it/s 15.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 23/23 10.4it/s 2.2s.1s
#                    all      0.864      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/10      1.11G     0.3412         14        224: 100% ━━━━━━━━━━━━ 208/208 13.1it/s 15.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 23/23 10.5it/s 2.2s0.2s
#                    all      0.867      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/10      1.11G      0.308         14        224: 100% ━━━━━━━━━━━━ 208/208 13.2it/s 15.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 23/23 11.0it/s 2.1s0.1s
#                    all      0.875      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/10      1.11G     0.2746         14        224: 100% ━━━━━━━━━━━━ 208/208 13.2it/s 15.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 23/23 11.0it/s 2.1s0.1s
#                    all      0.881      0.997
#
# 10 epochs completed in 0.052 hours.
# Optimizer stripped from /Users/car/CSUChico/CSCI611/yolov8/runs/classify/runs/yolov8n_cls_stratified_10epochs/weights/last.pt, 3.0MB
# Optimizer stripped from /Users/car/CSUChico/CSCI611/yolov8/runs/classify/runs/yolov8n_cls_stratified_10epochs/weights/best.pt, 3.0MB
#
# Validating /Users/car/CSUChico/CSCI611/yolov8/runs/classify/runs/yolov8n_cls_stratified_10epochs/weights/best.pt...
# Ultralytics 8.4.41 🚀 Python-3.10.20 torch-2.11.0 MPS (Apple M5)
# YOLOv8n-cls summary (fused): 30 layers, 1,446,409 parameters, 0 gradients, 3.3 GFLOPs
# train: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/train... found 3326 images in 9 classes ✅
# val: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/val... found 713 images in 9 classes ✅
# test: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/test... found 713 images in 9 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 23/23 11.0it/s 2.1s0.1s
#                    all      0.881      0.997
# Speed: 0.1ms preprocess, 0.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /Users/car/CSUChico/CSCI611/yolov8/runs/classify/runs/yolov8n_cls_stratified_10epochs
# Training ended at: 2026-05-13 21:15:21
# Elapsed time: 0h 3m 10s

# %%
#code to actually test the model, and see what the test accuracy is
#very important was missing before but we need test accuracy after each run to verify whether or not the model is improving or not

from ultralytics import YOLO

# Load best trained model
model = YOLO("runs/classify/runs/yolov8n_cls_stratified_10epochs/weights/best.pt")

# Evaluate on test dataset
metrics = model.val(
    data="outputs_for_YOLO_classification_stratified_dataset",
    split="test"
)

print("\nEvaluation Metrics:")
print(metrics)

print(f"\nTop-1 Accuracy: {metrics.top1:.4f}")
print(f"Top-5 Accuracy: {metrics.top5:.4f}")
# Out:
# Ultralytics 8.4.41 🚀 Python-3.10.20 torch-2.11.0 CPU (Apple M5)
# YOLOv8n-cls summary (fused): 30 layers, 1,446,409 parameters, 0 gradients, 3.3 GFLOPs
# train: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/train... found 3326 images in 9 classes ✅
# val: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/val... found 713 images in 9 classes ✅
# test: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/test... found 713 images in 9 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 686.0±195.7 MB/s, size: 190.6 KB)
# test: Scanning /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/test... 713 images, 0 corrupt: 100% ━━━━━━━━━━━━ 713/713 11.1Kit/s 0.1s
# test: New cache created: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/test.cache
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 45/45 6.0it/s 7.5s0.2s
#                    all      0.884      0.999
# Speed: 0.0ms preprocess, 7.9ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /Users/car/CSUChico/CSCI611/yolov8/runs/classify/val
#
# Evaluation Metrics:
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x1341fb190>
# curves: []
# curves_results: []
# fitness: 0.9410939812660217
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.8835904598236084, 'metrics/accuracy_top5': 0.9985975027084351, 'fitness': 0.9410939812660217}
# save_dir: PosixPath('/Users/car/CSUChico/CSCI611/yolov8/runs/classify/val')
# speed: {'preprocess': 0.0004132230002948195, 'inference': 7.871572113605103, 'loss': 4.330434843937495e-05, 'postprocess': 0.00012126507667865771}
# top1: 0.8835904598236084
# top5: 0.9985975027084351
#
# Top-1 Accuracy: 0.8836
# Top-5 Accuracy: 0.9986

# %%
from ultralytics import YOLO
import torch
from datetime import datetime

# Start time
start_time = datetime.now()
print("Training started at:", start_time.strftime("%Y-%m-%d %H:%M:%S"))
# ======> Train the model
def main():

    # 1. Check for NVIDIA GPU (Colab/PC)
    # 2. Check for Apple Silicon (Mac)
    # 3. Default to CPU
    device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"

    print(f"I am training on: {device.upper()}")

    ### Clasify model.
    model = YOLO("yolov8n-cls.pt")
    
    model.train(
        ### data="realwaste-yolo/RealWaste/data.yaml",
        ### '/content/RealWaste/data.yaml'
        data="outputs_for_YOLO_classification_stratified_dataset",
        epochs=60, ###==> Hyper-parameters
        freeze=8,
        lr0=1e-4,
        lrf=0.01,
        momentum=0.9,
        weight_decay=5e-4,
        dropout=0.2,
        # Augmentation
        hsv_h=0.015,
        hsv_s=0.7,
        hsv_v=0.4,
        degrees=10.0,
        translate=0.1,
        scale=0.3,
        fliplr=0.5,
        imgsz=224,
        batch=64,
        patience=15,
        optimizer="AdamW",
        label_smoothing=0.1,
        device=device,
        workers=5,  # safer in Jupyter if needed
        pretrained=True,
        verbose=True,
        project="runs",
        name="yolov8n_cls_stratified_10epochs"
    )

if __name__ == "__main__":
    main()
# <=====

# End time
end_time = datetime.now()
print("Training ended at:", end_time.strftime("%Y-%m-%d %H:%M:%S"))

# Elapsed time
elapsed = end_time - start_time

# Format nicely (hours, minutes, seconds)
hours, remainder = divmod(elapsed.total_seconds(), 3600)
minutes, seconds = divmod(remainder, 60)

print(f"Elapsed time: {int(hours)}h {int(minutes)}m {int(seconds)}s")
# Out:
# Training started at: 2026-05-13 21:35:46
# I am training on: MPS
# New https://pypi.org/project/ultralytics/8.4.50 available 😃 Update with 'pip install -U ultralytics'
# WARNING ⚠️ 'label_smoothing' is deprecated and will be removed in the future.
# Ultralytics 8.4.41 🚀 Python-3.10.20 torch-2.11.0 MPS (Apple M5)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=outputs_for_YOLO_classification_stratified_dataset, degrees=10.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.2, dynamic=False, embed=None, end2end=None, epochs=60, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=8, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.9, mosaic=1.0, multi_scale=0.0, name=yolov8n_cls_stratified_10epochs-3, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/Users/car/CSUChico/CSCI611/yolov8/runs/classify/runs/yolov8n_cls_stratified_10epochs-3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.3, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=5, workspace=None
# train: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/train... found 3326 images in 9 classes ✅
# val: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/val... found 713 images in 9 classes ✅
# test: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/test... found 713 images in 9 classes ✅
# Overriding model.yaml nc=1000 with nc=9
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    341769  ultralytics.nn.modules.head.Classify         [256, 9]
# YOLOv8n-cls summary: 56 layers, 1,449,817 parameters, 1,449,817 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# Freezing layer 'model.0.conv.weight'
# Freezing layer 'model.0.bn.weight'
# Freezing layer 'model.0.bn.bias'
# Freezing layer 'model.1.conv.weight'
# Freezing layer 'model.1.bn.weight'
# Freezing layer 'model.1.bn.bias'
# Freezing layer 'model.2.cv1.conv.weight'
# Freezing layer 'model.2.cv1.bn.weight'
# Freezing layer 'model.2.cv1.bn.bias'
# Freezing layer 'model.2.cv2.conv.weight'
# Freezing layer 'model.2.cv2.bn.weight'
# Freezing layer 'model.2.cv2.bn.bias'
# Freezing layer 'model.2.m.0.cv1.conv.weight'
# Freezing layer 'model.2.m.0.cv1.bn.weight'
# Freezing layer 'model.2.m.0.cv1.bn.bias'
# Freezing layer 'model.2.m.0.cv2.conv.weight'
# Freezing layer 'model.2.m.0.cv2.bn.weight'
# Freezing layer 'model.2.m.0.cv2.bn.bias'
# Freezing layer 'model.3.conv.weight'
# Freezing layer 'model.3.bn.weight'
# Freezing layer 'model.3.bn.bias'
# Freezing layer 'model.4.cv1.conv.weight'
# Freezing layer 'model.4.cv1.bn.weight'
# Freezing layer 'model.4.cv1.bn.bias'
# Freezing layer 'model.4.cv2.conv.weight'
# Freezing layer 'model.4.cv2.bn.weight'
# Freezing layer 'model.4.cv2.bn.bias'
# Freezing layer 'model.4.m.0.cv1.conv.weight'
# Freezing layer 'model.4.m.0.cv1.bn.weight'
# Freezing layer 'model.4.m.0.cv1.bn.bias'
# Freezing layer 'model.4.m.0.cv2.conv.weight'
# Freezing layer 'model.4.m.0.cv2.bn.weight'
# Freezing layer 'model.4.m.0.cv2.bn.bias'
# Freezing layer 'model.4.m.1.cv1.conv.weight'
# Freezing layer 'model.4.m.1.cv1.bn.weight'
# Freezing layer 'model.4.m.1.cv1.bn.bias'
# Freezing layer 'model.4.m.1.cv2.conv.weight'
# Freezing layer 'model.4.m.1.cv2.bn.weight'
# Freezing layer 'model.4.m.1.cv2.bn.bias'
# Freezing layer 'model.5.conv.weight'
# Freezing layer 'model.5.bn.weight'
# Freezing layer 'model.5.bn.bias'
# Freezing layer 'model.6.cv1.conv.weight'
# Freezing layer 'model.6.cv1.bn.weight'
# Freezing layer 'model.6.cv1.bn.bias'
# Freezing layer 'model.6.cv2.conv.weight'
# Freezing layer 'model.6.cv2.bn.weight'
# Freezing layer 'model.6.cv2.bn.bias'
# Freezing layer 'model.6.m.0.cv1.conv.weight'
# Freezing layer 'model.6.m.0.cv1.bn.weight'
# Freezing layer 'model.6.m.0.cv1.bn.bias'
# Freezing layer 'model.6.m.0.cv2.conv.weight'
# Freezing layer 'model.6.m.0.cv2.bn.weight'
# Freezing layer 'model.6.m.0.cv2.bn.bias'
# Freezing layer 'model.6.m.1.cv1.conv.weight'
# Freezing layer 'model.6.m.1.cv1.bn.weight'
# Freezing layer 'model.6.m.1.cv1.bn.bias'
# Freezing layer 'model.6.m.1.cv2.conv.weight'
# Freezing layer 'model.6.m.1.cv2.bn.weight'
# Freezing layer 'model.6.m.1.cv2.bn.bias'
# Freezing layer 'model.7.conv.weight'
# Freezing layer 'model.7.bn.weight'
# Freezing layer 'model.7.bn.bias'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 360.9±95.8 MB/s, size: 133.2 KB)
# train: Scanning /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/train... 3326 images, 0 corrupt: 100% ━━━━━━━━━━━━ 3326/3326 1.7Git/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 584.2±233.7 MB/s, size: 152.3 KB)
# val: Scanning /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/val... 713 images, 0 corrupt: 100% ━━━━━━━━━━━━ 713/713 747.6Mit/s 0.0s
# optimizer: AdamW(lr=0.0001, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to /Users/car/CSUChico/CSCI611/yolov8/runs/classify/runs/yolov8n_cls_stratified_10epochs-3
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/60      1.12G      1.809         62        224: 100% ━━━━━━━━━━━━ 52/52 4.2it/s 12.4s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.7it/s 2.2s0.5s
#                    all      0.512      0.935
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/60      1.12G      1.314         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s0.5s
#                    all       0.64       0.98
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/60      1.12G       1.09         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.677      0.982
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/60      1.12G     0.9475         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s0.4s
#                    all      0.693      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/60      1.12G      0.871         62        224: 100% ━━━━━━━━━━━━ 52/52 4.4it/s 11.7s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.712      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/60      1.12G     0.8142         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.727       0.99
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/60      1.12G     0.7537         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.2s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.739       0.99
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/60      1.12G     0.7158         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.755       0.99
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/60      1.12G     0.6966         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all       0.76      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/60      1.12G     0.6548         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.781      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/60      1.12G     0.6167         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.784      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/60      1.12G     0.5883         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.2s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.799      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/60      1.12G     0.5789         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.2s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.792      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/60      1.12G     0.5536         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.2s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.806      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/60      1.12G     0.5412         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.809      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/60      1.12G     0.5359         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.813      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/60      1.12G     0.5026         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.819      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/60      1.12G     0.4876         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.2s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.822      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/60      1.12G     0.4807         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.2s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.823      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/60      1.12G     0.4642         62        224: 100% ━━━━━━━━━━━━ 52/52 4.1it/s 12.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.2s0.5s
#                    all      0.836      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/60      1.12G     0.4526         62        224: 100% ━━━━━━━━━━━━ 52/52 4.2it/s 12.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.833      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/60      1.12G     0.4605         62        224: 100% ━━━━━━━━━━━━ 52/52 4.4it/s 11.8s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s0.5s
#                    all      0.844      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/60      1.12G     0.4239         62        224: 100% ━━━━━━━━━━━━ 52/52 4.4it/s 11.9s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.849      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/60      1.12G     0.4277         62        224: 100% ━━━━━━━━━━━━ 52/52 4.4it/s 11.9s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s0.4s
#                    all       0.85      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/60      1.12G     0.4181         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.2s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.854      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/60      1.12G     0.4124         62        224: 100% ━━━━━━━━━━━━ 52/52 4.4it/s 11.9s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s0.5s
#                    all      0.857      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/60      1.12G      0.398         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.2s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.854      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/60      1.12G     0.3844         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s0.5s
#                    all      0.861      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/60      1.12G     0.3673         62        224: 100% ━━━━━━━━━━━━ 52/52 4.4it/s 11.8s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.1s0.5s
#                    all      0.858      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/60      1.12G     0.3807         62        224: 100% ━━━━━━━━━━━━ 52/52 4.4it/s 11.8s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all       0.85      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/60      1.12G     0.3645         62        224: 100% ━━━━━━━━━━━━ 52/52 4.4it/s 11.7s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.858      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/60      1.12G     0.3683         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.858      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/60      1.12G      0.361         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.2s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.857      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/60      1.12G     0.3434         62        224: 100% ━━━━━━━━━━━━ 52/52 4.3it/s 12.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all      0.858      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/60      1.12G     0.3526         62        224: 100% ━━━━━━━━━━━━ 52/52 4.4it/s 11.7s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.858      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/60      1.12G     0.3359         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.858      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/60      1.12G     0.3272         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.868      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/60      1.12G     0.3281         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.865      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/60      1.12G     0.3173         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.867      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/60      1.12G     0.3196         62        224: 100% ━━━━━━━━━━━━ 52/52 4.5it/s 11.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.9it/s 2.0s0.4s
#                    all      0.864      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/60      1.12G     0.3169         62        224: 100% ━━━━━━━━━━━━ 52/52 4.6it/s 11.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.857      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/60      1.12G     0.3129         62        224: 100% ━━━━━━━━━━━━ 52/52 4.6it/s 11.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.1s0.5s
#                    all       0.86      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/60      1.12G     0.3082         62        224: 100% ━━━━━━━━━━━━ 52/52 4.6it/s 11.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.0it/s 2.0s0.4s
#                    all      0.865      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/60      1.12G     0.3086         62        224: 100% ━━━━━━━━━━━━ 52/52 4.6it/s 11.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.853      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/60      1.12G     0.3019         62        224: 100% ━━━━━━━━━━━━ 52/52 4.6it/s 11.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.857      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/60      1.12G     0.3022         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all       0.86      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/60      1.12G     0.2959         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.856      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/60      1.12G     0.2974         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.854      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/60      1.12G     0.2942         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.864      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/60      1.12G     0.2981         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.863      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       51/60      1.12G     0.2839         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.1it/s 1.9s0.4s
#                    all      0.864      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       52/60      1.12G     0.2953         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.861      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       53/60      1.12G     0.2927         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all       0.86      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       54/60      1.12G     0.2863         62        224: 100% ━━━━━━━━━━━━ 52/52 4.7it/s 11.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.861      0.997
# EarlyStopping: Training stopped early as no improvement observed in last 15 epochs. Best results observed at epoch 39, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 54 epochs completed in 0.210 hours.
# Optimizer stripped from /Users/car/CSUChico/CSCI611/yolov8/runs/classify/runs/yolov8n_cls_stratified_10epochs-3/weights/last.pt, 3.0MB
# Optimizer stripped from /Users/car/CSUChico/CSCI611/yolov8/runs/classify/runs/yolov8n_cls_stratified_10epochs-3/weights/best.pt, 3.0MB
#
# Validating /Users/car/CSUChico/CSCI611/yolov8/runs/classify/runs/yolov8n_cls_stratified_10epochs-3/weights/best.pt...
# Ultralytics 8.4.41 🚀 Python-3.10.20 torch-2.11.0 MPS (Apple M5)
# YOLOv8n-cls summary (fused): 30 layers, 1,446,409 parameters, 0 gradients, 3.3 GFLOPs
# train: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/train... found 3326 images in 9 classes ✅
# val: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/val... found 713 images in 9 classes ✅
# test: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/test... found 713 images in 9 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 6/6 3.2it/s 1.9s0.4s
#                    all      0.867      0.997
# Speed: 0.0ms preprocess, 0.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /Users/car/CSUChico/CSCI611/yolov8/runs/classify/runs/yolov8n_cls_stratified_10epochs-3
# Training ended at: 2026-05-13 21:48:25
# Elapsed time: 0h 12m 38s

# %%
#code to actually test the model, and see what the test accuracy is
#very important was missing before but we need test accuracy after each run to verify whether or not the model is improving or not

from ultralytics import YOLO

# Load best trained model
model = YOLO("runs/classify/runs/yolov8n_cls_stratified_10epochs-3/weights/best.pt")

# Evaluate on test dataset
metrics = model.val(
    data="outputs_for_YOLO_classification_stratified_dataset",
    split="test"
)

print("\nEvaluation Metrics:")
print(metrics)

print(f"\nTop-1 Accuracy: {metrics.top1:.4f}")
print(f"Top-5 Accuracy: {metrics.top5:.4f}")
# Out:
# Ultralytics 8.4.41 🚀 Python-3.10.20 torch-2.11.0 CPU (Apple M5)
# YOLOv8n-cls summary (fused): 30 layers, 1,446,409 parameters, 0 gradients, 3.3 GFLOPs
# train: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/train... found 3326 images in 9 classes ✅
# val: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/val... found 713 images in 9 classes ✅
# test: /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/test... found 713 images in 9 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 646.3±135.7 MB/s, size: 190.6 KB)
# test: Scanning /Users/car/CSUChico/CSCI611/yolov8/outputs_for_YOLO_classification_stratified_dataset/test... 713 images, 0 corrupt: 100% ━━━━━━━━━━━━ 713/713 332.3Mit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 45/45 5.9it/s 7.6s0.2s
#                    all      0.882      0.999
# Speed: 0.0ms preprocess, 7.9ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /Users/car/CSUChico/CSCI611/yolov8/runs/classify/val-3
#
# Evaluation Metrics:
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x1341dde40>
# curves: []
# curves_results: []
# fitness: 0.9403927326202393
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.8821879625320435, 'metrics/accuracy_top5': 0.9985975027084351, 'fitness': 0.9403927326202393}
# save_dir: PosixPath('/Users/car/CSUChico/CSCI611/yolov8/runs/classify/val-3')
# speed: {'preprocess': 0.00040538288426515614, 'inference': 7.8561592440379755, 'loss': 4.4706874096153506e-05, 'postprocess': 9.262832851497898e-05}
# top1: 0.8821879625320435
# top5: 0.9985975027084351
#
# Top-1 Accuracy: 0.8822
# Top-5 Accuracy: 0.9986
